# %% [markdown]
# # 13장 연습문제

# %%
import pandas as pd
df = pd.read_csv('high_school_2019.csv')



print('-'*50)
df2 = df.iloc[:,[2,3,4,5,6,7]]
df2
# Out:
# --------------------------------------------------
#        1학년 학급수   1학년 학생수   2학년 학급수   2학년 학생수   3학년 학급수   3학년 학생수
# 0            5       150         5       149         5       143
# 1            8       239         8       228         8       270
# 2            6       182         6       174         6       169
# 3           11       282        11       262        11       288
# 4            8       210         8       183         8       221
# ...        ...       ...       ...       ...       ...       ...
# 2393        11       279        11       279        11       305
# 2394         8       151         8       141         8       135
# 2395         4        76         5        91         5       103
# 2396         4        99         4        95         4        92
# 2397         5       116         5        98         5       126
#
# [2398 rows x 6 columns]

# %%
import pandas as pd
df = pd.read_csv('high_school_2019.csv')
df2 = df.iloc[:,[2,3,4,5,6,7]]

df2['총학생수']=df2.iloc[:,[1,3,5]].sum(axis=1)
df2
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#        1학년 학급수   1학년 학생수   2학년 학급수   2학년 학생수   3학년 학급수   3학년 학생수  총학생수
# 0            5       150         5       149         5       143   442
# 1            8       239         8       228         8       270   737
# 2            6       182         6       174         6       169   525
# 3           11       282        11       262        11       288   832
# 4            8       210         8       183         8       221   614
# ...        ...       ...       ...       ...       ...       ...   ...
# 2393        11       279        11       279        11       305   863
# ...

# %%
import seaborn as sns
import pandas as pd
df = pd.read_csv('high_school_2019.csv')

total = df2.sum(axis=0)
df3 = total.iloc[[1,3,5]]

df3.index = ['1학년','2학년','3학년']



df3.plot.bar(rot=1)
plt.show()

# %% [markdown]
# #  14장 연습문제

# %%
import seaborn as sns
import pandas as pd
df = pd.read_csv('population_age_2020.csv')
df1 = df[['지역','100세 이상','총인구수']]
frame = pd.DataFrame(df1)
age_100 = frame.sort_values(by=['100세 이상'], ascending=False)
age_100 = age_100.reset_index(drop=True)
age_100
# Out:
#       지역  100세 이상      총인구수
# 0     서울     6380   9736962
# 1    경기도     4010  13265377
# 2     부산     1807   3410925
# 3   경상북도      960   2658956
# 4     인천      908   2954955
# 5   충청남도      885   2120995
# 6   전라남도      822   1861894
# 7   전라북도      817   1815112
# 8    강원도      803   1539521
# 9   경상남도      739   3358828
# 10    대구      694   2432883
# 11  충청북도      541   1598599
# 12    광주      405   1456121
# 13    대전      339   1473125
# 14   제주도      266    670876
# 15    울산      160   1145710
# 16    세종       55    343788
