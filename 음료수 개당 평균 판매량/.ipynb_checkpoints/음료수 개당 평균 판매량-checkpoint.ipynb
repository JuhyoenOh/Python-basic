# %%
import numpy as np
import pandas as pd
f = pd.read_csv('sales_data.csv', encoding='CP949')

f
# Out:
#          YM CATEGORY  ITEM_CNT   QTY  PRICE  MAXTEMP  SALEDAY  RAIN_DAY  \
# 0    200901     건강음료        37  1410   1543        4   126753       151
# 1    200902     건강음료        37  1209   1543        9   113399      3014
# 2    200903     건강음료        38  1348   1547       12   129162      1383
# 3    200904     건강음료        38  1377   1500       19   126277      3564
# 4    200905     건강음료        40  1406   1528       25   129584      9288
# ..      ...      ...       ...   ...    ...      ...      ...       ...
# 401  201308      차음료        50  3894   1556       31   240142     22284
# 402  201309      차음료        49  3708   1553       26   231662     13699
# 403  201310      차음료        49  3413   1553       21   239981      3011
# 404  201311      차음료        50  2615   1548       12   232854      2944
# 405  201312      차음료        50  2443   1548        5   240458       202
#
#      HOLIDAY
# 0         12
# 1          8
# 2          9
# 3          8
# 4         12
# ..       ...
# 401       10
# 402       12
# 403       10
# 404        9
# 405       10
#
# [406 rows x 9 columns]

# %%
len(f)
# Out:
# 406

# %%
k[3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-1875b50fbdce> in <module>
# ----> 1 k[3]
#
# NameError: name 'k' is not defined

# %%
a=[]
b=[]
for i in range(len(f)):
    k=f.loc[i]
    
    if k[1]=='스포츠,이온음료' :
        a.append(k)
    elif k[1]=='에너지음료':
        b.append(k)

# %%
a=pd.DataFrame(a)

# %%
b=pd.DataFrame(b)

# %%
a_YM=a.loc[:,['YM']]
a_QTY=a.loc[:,['QTY']]


b_YM=b.loc[:,['YM']]
b_QTY=b.loc[:,['QTY']]

# %%
import numpy as np
import matplotlib.pyplot as mpl
import matplotlib.pyplot as plt
mpl.rcParams['axes.unicode_minus'] = False #minus 표시
mpl.rc('font', family='Malgun Gothic')  # 폰트 설정(맑은 고딕)
# %matplotlib inline

# %%
#각 월 판매량

xdata1 = a_YM
xdata2 = b_YM
ydata1 = a_QTY
ydata2 = b_QTY

fig, axs = plt.subplots(nrows =1 , ncols=2, figsize=(9,5), sharex=True, sharey=True)
ax = axs[0]
ax.plot(xdata1,ydata1, color='red', linestyle='--',marker='o')
ax.set_title('스포츠,이온음료')

ax = axs[1]
ax.plot(xdata2, ydata2, linestyle='--',marker='o')
ax.set_title('에너지음료')


plt.subplots_adjust(left = 0.1, right=0.9, bottom=0.1, top=1, wspace=0.2, hspace=0.3)



plt.show()

# %%
# 개당 평균 판매량

a['개당 평균 판매량'] = (a['QTY']/a['ITEM_CNT'])
b['개당 평균 판매량'] = (b['QTY']/b['ITEM_CNT'])

# %%
a
# Out:
#          YM  CATEGORY  ITEM_CNT   QTY  PRICE  MAXTEMP  SALEDAY  RAIN_DAY  \
# 180  200901  스포츠,이온음료        12   622   1508        4   126753       151
# 181  200902  스포츠,이온음료        12   660   1533        9   113399      3014
# 182  200903  스포츠,이온음료        12   794   1554       12   129162      1383
# 183  200904  스포츠,이온음료        12  1119   1529       19   126277      3564
# 184  200905  스포츠,이온음료        12  1524   1529       25   129584      9288
# 185  200906  스포츠,이온음료        13  1480   1488       27   123218      9998
# 186  200907  스포츠,이온음료        15  1509   1490       28   131083     17405
# 263  201202    에너지음료         5   435   1660        5   186880       377
# 264  201203    에너지음료         5   732   1660       11   212945      6556
# 265  201204    에너지음료         4  1183   1350       18   209151     17042
# 266  201205    에너지음료         6  1428   1633       24   215673      2095
# 267  201206    에너지음료         7  1573   1543       28   215525      8865
# 268  201207    에너지음료         7  1825   1543       29   203590     25076
# 269  201208    에너지음료         7  2425   1543       30   228142     32385
# 270  201209    에너지음료         9  2601   1522       25   223581     23569
# 271  201210    에너지음료        10  2455   1560       21   233331     11111
# 272  201211    에너지음료        11  1774   1555       11   229144      4805
# 273  201212    에너지음료        12  1521   1508        2   239129      3706
# 274  201301    에너지음료        12  1246   1508        2   240416      2528
# 275  201302    에너지음료        12   951   1433        5   217015      6667
# 276  201303    에너지음료        16  1593   1569       12   243648      4364
# 277  201304    에너지음료        17  1935   1535       15   237340      6727
# 278  201305    에너지음료        17  2073   1535       23   245068     17217
# 279  201306    에너지음료        17  2169   1594       28   236180      7360
# 280  201307    에너지음료        17  2606   1594       29   241687     41344
# 281  201308    에너지음료        17  2256   1459       31   240142     22284
# 282  201309    에너지음료        17  2254   1488       26   231662     13699
# 283  201310    에너지음료        18  1981   1567       21   239981      3011
# 284  201311    에너지음료        18  1082   1567       12   232854      2944
# 285  201312    에너지음료        17   988   1541        5   240458       202
#
#      HOLIDAY   개당 평균 판매량
# 240        9   24.000000
# 241        8   96.500000
# 242       12   93.500000
# 243        8  146.000000
# 244        9  135.500000
# 245        9  127.750000
# 246       11   87.000000
# 247       10   29.000000
# 248        8   79.333333
# 249        8   74.000000
# 250       10  185.000000
# 251       11  207.000000
# 252        9  261.000000
# 253        9  340.000000
# 254       10   25.000000
# 255        9   39.666667
# 256       10  137.333333
# 257        9   50.000000
# 258       10  116.750000
# 259       11  140.500000
# 260        8  109.500000
# 261        9  128.500000
# 262       11   96.500000
# 263        8   87.000000
# 264       10  146.400000
# 265        9  295.750000
# 266       10  238.000000
# 267       10  224.714286
# 268        9  260.714286
# 269        9  346.428571
# 270       10  289.000000
# 271       10  245.500000
# 272        8  161.272727
# 273       11  126.750000
# 274        9  103.833333
# 275        9   79.250000
# 276       11   99.562500
# 277        8  113.823529
# 278       10  121.941176
# 279       11  127.588235
# 280        8  153.294118
# 281       10  132.705882
# 282       12  132.588235
# 283       10  110.055556
# 284        9   60.111111
# 285       10   58.117647

# %%
a_YM=a.loc[:,['YM']]
a_QTY_1=a.loc[:,['개당 평균 판매량']]


b_YM=b.loc[:,['YM']]
b_QTY_2=b.loc[:,['개당 평균 판매량']]

# %%
x_1 = a_YM
x_2 = b_YM
y_1 = a_QTY_1
y_2 = b_QTY_2

fig, axs = plt.subplots(nrows =1 , ncols=2, figsize=(9,5), sharex=True, sharey=True)
ax = axs[0]
ax.plot(xdata1,y_1, color='red', linestyle='--')
ax.set_title('스포츠,이온음료')

ax = axs[1]
ax.plot(xdata2, y_2, linestyle='--')
ax.set_title('에너지음료')


plt.subplots_adjust(left = 0.1, right=0.9, bottom=0.1, top=1, wspace=0.2, hspace=0.3)
plt.ylim(0, 400)


plt.show()
